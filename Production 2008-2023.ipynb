# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
file_path = pd.read_csv("DAUPSA.csv")
new_df = pd.DataFrame ({
    "Country": ["USA"] * len(file_path),
    "Date": file_path["DATE"],
    "Production (Thousands)": file_path["Domestic Production"]
})

new_df
# Out:
#    Country        Date  Production (Thousands)
# 0      USA  2008-01-01              325.566667
# 1      USA  2008-04-01              301.000000
# 2      USA  2008-07-01              342.266667
# 3      USA  2008-10-01              271.766667
# 4      USA  2009-01-01              132.300000
# ..     ...         ...                     ...
# 58     USA  2022-07-01              149.000000
# 59     USA  2022-10-01              141.666667
# 60     USA  2023-01-01              147.400000
# 61     USA  2023-04-01              147.166667
# 62     USA  2023-07-01              154.000000
#
# [63 rows x 3 columns]

# %%
plt.figure(figsize=(25, 6))
plt.plot(new_df['Date'], new_df["Production (Thousands)"], marker='o', linestyle='-', color='blue')
plt.title('Domestic Production Over Time')
plt.xlabel('Dates')
plt.ylabel('Domestic Production (Thousands)')
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join("Data Output", 'domestic_production_plot.png'))
plt.show()

# %%
plt.figure(figsize=(25, 6))
plt.bar(new_df['Date'], new_df["Production (Thousands)"], color='blue')
plt.title('Domestic Production Over Time (Bar Plot)')
plt.xlabel('Dates')
plt.ylabel('Domestic Production (Thousands)')
plt.xticks(rotation=90)
plt.tight_layout()
plt.savefig(os.path.join("Data Output", 'domestic_production_bar_plot.png'))
plt.show()

# %%
#Covid was discovered in late 2019 but offically announced in January 2020 and CDC declaration ended in May 2023
